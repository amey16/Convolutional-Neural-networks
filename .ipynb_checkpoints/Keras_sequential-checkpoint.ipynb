# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
from sklearn.model_selection import train_test_split

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import utils

# %%
dataset = read_csv('fashion-mnist_test.csv')
dataset = dataset.values

# %%
for i in range(10):
    plt.figure()
    plt.imshow(dataset[i,1:].reshape(28,28), cmap='gray')

# %%
X, y = dataset[:, 1:]/255, dataset[:, 0]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

y_train = utils.to_categorical(y_train)
y_test  = utils.to_categorical(y_test)

# %%
model = Sequential()

model.add(Dense(256, input_shape=(784,)))
model.add(Activation('sigmoid'))

model.add(Dense(64))
model.add(Activation('tanh'))

model.add(Dense(10))
model.add(Activation('softmax'))

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 256)               200960
# _________________________________________________________________
# activation_9 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                16448
# _________________________________________________________________
# activation_10 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                650
# _________________________________________________________________
# activation_11 (Activation)   (None, 10)                0
# =================================================================
# Total params: 218,058
# Trainable params: 218,058
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Initialize Weights
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# %%
hist = model.fit(X_train, y_train,
          shuffle=True,
          epochs=40,
          batch_size=128,
          validation_data=(X_test, y_test)
         )
# Out:
# Epoch 1/40
# 63/63 [==============================] - 4s 27ms/step - loss: 2.1827 - accuracy: 0.2989 - val_loss: 2.0647 - val_accuracy: 0.4400
# Epoch 2/40
# 63/63 [==============================] - 1s 10ms/step - loss: 1.9577 - accuracy: 0.5139 - val_loss: 1.8473 - val_accuracy: 0.5380
# Epoch 3/40
# 63/63 [==============================] - 1s 8ms/step - loss: 1.7521 - accuracy: 0.5803 - val_loss: 1.6534 - val_accuracy: 0.6030
# Epoch 4/40
# 63/63 [==============================] - 1s 11ms/step - loss: 1.5780 - accuracy: 0.6219 - val_loss: 1.4946 - val_accuracy: 0.6480
# Epoch 5/40
# 63/63 [==============================] - 1s 10ms/step - loss: 1.4370 - accuracy: 0.6600 - val_loss: 1.3681 - val_accuracy: 0.6625
# Epoch 6/40
# 63/63 [==============================] - 1s 11ms/step - loss: 1.3249 - accuracy: 0.6745 - val_loss: 1.2687 - val_accuracy: 0.6970
# Epoch 7/40
# 63/63 [==============================] - 1s 11ms/step - loss: 1.2346 - accuracy: 0.6896 - val_loss: 1.1844 - val_accuracy: 0.7020
# Epoch 8/40
# 63/63 [==============================] - 1s 9ms/step - loss: 1.1620 - accuracy: 0.7021 - val_loss: 1.1177 - val_accuracy: 0.7065
# Epoch 9/40
# 63/63 [==============================] - 1s 9ms/step - loss: 1.1017 - accuracy: 0.7095 - val_loss: 1.0658 - val_accuracy: 0.7180
# Epoch 10/40
# 63/63 [==============================] - 1s 10ms/step - loss: 1.0509 - accuracy: 0.7190 - val_loss: 1.0180 - val_accuracy: 0.7050
# Epoch 11/40
# 63/63 [==============================] - 1s 10ms/step - loss: 1.0081 - accuracy: 0.7190 - val_loss: 0.9765 - val_accuracy: 0.7350
# Epoch 12/40
# 63/63 [==============================] - 1s 9ms/step - loss: 0.9708 - accuracy: 0.7260 - val_loss: 0.9404 - val_accuracy: 0.7280
# Epoch 13/40
# 63/63 [==============================] - 1s 10ms/step - loss: 0.9385 - accuracy: 0.7279 - val_loss: 0.9086 - val_accuracy: 0.7360
# Epoch 14/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.9092 - accuracy: 0.7308 - val_loss: 0.8850 - val_accuracy: 0.7380
# Epoch 15/40
# 63/63 [==============================] - 1s 10ms/step - loss: 0.8842 - accuracy: 0.7345 - val_loss: 0.8563 - val_accuracy: 0.7395
# Epoch 16/40
# 63/63 [==============================] - 1s 10ms/step - loss: 0.8614 - accuracy: 0.7379 - val_loss: 0.8353 - val_accuracy: 0.7475
# Epoch 17/40
# 63/63 [==============================] - 1s 11ms/step - loss: 0.8403 - accuracy: 0.7415 - val_loss: 0.8152 - val_accuracy: 0.7485
# Epoch 18/40
# 63/63 [==============================] - 1s 12ms/step - loss: 0.8220 - accuracy: 0.7440 - val_loss: 0.7969 - val_accuracy: 0.7500
# Epoch 19/40
# 63/63 [==============================] - 1s 11ms/step - loss: 0.8051 - accuracy: 0.7474 - val_loss: 0.7816 - val_accuracy: 0.7575
# Epoch 20/40
# 63/63 [==============================] - 1s 11ms/step - loss: 0.7896 - accuracy: 0.7487 - val_loss: 0.7706 - val_accuracy: 0.7590
# Epoch 21/40
# 63/63 [==============================] - 1s 10ms/step - loss: 0.7760 - accuracy: 0.7521 - val_loss: 0.7532 - val_accuracy: 0.7615
# Epoch 22/40
# 63/63 [==============================] - 1s 8ms/step - loss: 0.7633 - accuracy: 0.7523 - val_loss: 0.7428 - val_accuracy: 0.7620
# Epoch 23/40
# 63/63 [==============================] - 1s 10ms/step - loss: 0.7512 - accuracy: 0.7534 - val_loss: 0.7295 - val_accuracy: 0.7655
# Epoch 24/40
# 63/63 [==============================] - 1s 10ms/step - loss: 0.7403 - accuracy: 0.7571 - val_loss: 0.7206 - val_accuracy: 0.7700
# Epoch 25/40
# 63/63 [==============================] - 1s 11ms/step - loss: 0.7293 - accuracy: 0.7574 - val_loss: 0.7096 - val_accuracy: 0.7635
# Epoch 26/40
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7197 - accuracy: 0.7601 - val_loss: 0.7061 - val_accuracy: 0.7690
# Epoch 27/40
# 63/63 [==============================] - 1s 10ms/step - loss: 0.7115 - accuracy: 0.7601 - val_loss: 0.6921 - val_accuracy: 0.7675
# Epoch 28/40
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7026 - accuracy: 0.7634 - val_loss: 0.6874 - val_accuracy: 0.7695
# Epoch 29/40
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6946 - accuracy: 0.7642 - val_loss: 0.6781 - val_accuracy: 0.7795
# Epoch 30/40
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6871 - accuracy: 0.7669 - val_loss: 0.6718 - val_accuracy: 0.7780
# Epoch 31/40
# 63/63 [==============================] - 1s 11ms/step - loss: 0.6800 - accuracy: 0.7670 - val_loss: 0.6622 - val_accuracy: 0.7810
# Epoch 32/40
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6729 - accuracy: 0.7684 - val_loss: 0.6592 - val_accuracy: 0.7780
# Epoch 33/40
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6669 - accuracy: 0.7705 - val_loss: 0.6522 - val_accuracy: 0.7800
# Epoch 34/40
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6610 - accuracy: 0.7726 - val_loss: 0.6464 - val_accuracy: 0.7785
# Epoch 35/40
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6552 - accuracy: 0.7764 - val_loss: 0.6404 - val_accuracy: 0.7855
# Epoch 36/40
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6497 - accuracy: 0.7753 - val_loss: 0.6372 - val_accuracy: 0.7840
# Epoch 37/40
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6442 - accuracy: 0.7755 - val_loss: 0.6331 - val_accuracy: 0.7860
# Epoch 38/40
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6390 - accuracy: 0.7789 - val_loss: 0.6277 - val_accuracy: 0.7840
# Epoch 39/40
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6342 - accuracy: 0.7816 - val_loss: 0.6228 - val_accuracy: 0.7855
# Epoch 40/40
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6293 - accuracy: 0.7814 - val_loss: 0.6163 - val_accuracy: 0.7895

# %%
hist.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.figure(0)
plt.title("Loss")
plt.plot(hist.history['loss'], 'r', label='Training')
plt.plot(hist.history['val_loss'], 'b', label='Testing')
plt.legend()
plt.show()

plt.figure(1)
plt.title("Accuracy")
plt.plot(hist.history['accuracy'], 'r', label='Training')
plt.plot(hist.history['val_accuracy'], 'b', label='Testing')
plt.legend()
plt.show()
